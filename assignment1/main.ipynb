# %% [markdown]
# # Assignment 1: Fundamental Machine Learning Models

# %% [markdown]
# # Linear Regression

# %% [markdown]
# # Logistic Regression

# %% [markdown]
# # Decision Tree

# %% [markdown]
# # Random Forest

# %% [markdown]
# # Support Vector Machine (SVM)
